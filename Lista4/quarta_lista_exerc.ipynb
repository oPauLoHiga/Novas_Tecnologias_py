# %% [markdown]
# # Quarta Lista de exercícios de Python
#
#
# Conteúdos contemplados:
#
# 1. Atribuição de variáveis
# 2. Números e operadores aritméticos
# 3. Strings
# 4. Listas
# 5. Dicionários
# 6. Tuplas
# 7. Conjuntos e booleanos
# 8. Métodos em Python
# 9. Funções
# 10. Expressões lambda, `map()` e `filter()`
# 11. Arquivos
#
# Como usar este material:
#
# 1. Leia cada enunciado com atenção.
# 2. Resolva cada exercício na célula logo abaixo.
# 3. Sempre que possível, teste com mais de um exemplo.
# 4. Nos exercícios que pedem explicação, use comentários no código.
# 5. Nos exercícios integradores, tente escrever soluções mais organizadas e legíveis.

# %% [markdown]
# ## Organização da lista
#
# A lista foi organizada em blocos temáticos e em progressão de dificuldade.
# Ela começa com exercícios mais diretos e termina com atividades integradoras.

# %% [markdown]
# ## Bloco 1, atribuição de variáveis

# %% [markdown]
# ### Exercício 1, criando variáveis
#
# Crie variáveis chamadas `nome`, `idade`, `altura` e `curso`. Atribua valores adequados a elas e depois exiba todas com `print()`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 2, tipagem dinâmica
#
# Crie uma variável chamada `valor`, atribua a ela um número inteiro, mostre seu tipo com `type()`, depois reatribua uma string à mesma variável e mostre novamente o tipo.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 3, regras de nomes
#
# Escreva, em comentários, quais dos nomes abaixo são válidos em Python e corrija os inválidos: `2nome`, `nome_completo`, `salario liquido`, `cidade`, `class`.

# %%
# Use comentários para responder

# %% [markdown]
# ### Exercício 4, troca de valores
#
# Crie as variáveis `a = 10` e `b = 25`. Troque os valores entre elas sem digitar os valores finais manualmente. Em seguida, mostre o resultado.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 5, múltiplas variáveis
#
# Atribua em uma única linha os valores `5`, `10` e `15` às variáveis `x`, `y` e `z`. Depois calcule a soma das três variáveis.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 6, analisando tipos
#
# Crie cinco variáveis, sendo uma do tipo inteiro, uma do tipo float, uma string, uma lista e um booleano. Mostre o valor e o tipo de cada uma.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 7, reaatribuição com contexto
#
# Crie a variável `funcionarios = 20`. Depois reatribua a mesma variável para uma lista contendo três nomes de funcionários e mostre os dois momentos do processo usando comentários explicativos.

# %%
# Dica: primeiro mostre o valor inteiro, depois reatribua a variável para uma lista

# %% [markdown]
# ### Exercício 8, mini cadastro sem input
#
# Crie variáveis para armazenar o nome de um aluno, sua matrícula, sua média e sua situação final. Depois exiba uma mensagem formatada com todas essas informações.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 2, números e operadores

# %% [markdown]
# ### Exercício 9, operações básicas
#
# Calcule e mostre o resultado das operações: soma, subtração, multiplicação, divisão, divisão inteira, resto da divisão e potência usando dois números de sua escolha.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 10, precedência
#
# Crie duas expressões numéricas diferentes que gerem resultados distintos por causa do uso de parênteses. Mostre ambas.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 11, área e perímetro
#
# Considere um retângulo de base 8 e altura 5. Calcule e mostre a área e o perímetro.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 12, média aritmética
#
# Crie três notas numéricas e calcule a média aritmética delas.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 13, divisão inteira e resto
#
# Considere o valor `37`. Descubra quantas dezenas completas existem nesse número e qual é o resto.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 14, potência e raiz
#
# Calcule o quadrado de 12, o cubo de 4 e a raiz quadrada de 81.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 15, expressão composta
#
# Calcule o valor da expressão `(10 + 5) * 2 / 3` e depois compare com `10 + 5 * 2 / 3`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 16, arredondamento
#
# Crie um número decimal com muitas casas e exiba o valor original, o valor arredondado com `round(..., 2)` e o valor arredondado com `round(..., 0)`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 17, conversão numérica
#
# Crie uma variável inteira, converta para float e mostre os tipos antes e depois da conversão.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 18, desafio com porcentagem
#
# Um produto custa `250.0` reais e recebe desconto de `18%`. Calcule o valor do desconto e o preço final.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 3, strings

# %% [markdown]
# ### Exercício 19, criando strings
#
# Crie três strings diferentes: uma com aspas simples, uma com aspas duplas e uma frase contendo aspas dentro do texto.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 20, concatenação
#
# Crie duas strings chamadas `nome` e `sobrenome` e depois junte as duas em uma terceira variável.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 21, comprimento da string
#
# Crie uma string com o nome de uma disciplina e descubra quantos caracteres ela possui usando `len()`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 22, indexação
#
# Dada a string `python`, mostre o primeiro caractere, o último caractere e o terceiro caractere.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 23, fatiamento
#
# Dada a string `universidade`, mostre: os três primeiros caracteres, os quatro últimos e a string pulando de dois em dois caracteres.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 24, imutabilidade
#
# Explique, em comentário, por que a instrução de tentar alterar diretamente um caractere de uma string gera erro. Depois mostre uma forma correta de obter uma nova string alterada.

# %%
# Escreva a explicação em comentário e faça um exemplo prático

# %% [markdown]
# ### Exercício 25, métodos de string
#
# Crie uma frase e aplique nela os métodos `.upper()`, `.lower()`, `.split()` e `.replace()`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 26, contagem e busca
#
# Na string `programacao em python`, descubra quantas vezes a letra `a` aparece e em que posição aparece a primeira ocorrência da palavra `python`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 27, formatação de strings
#
# Crie variáveis para nome, curso e semestre. Monte uma frase usando formatação com f-string.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 28, desafio com limpeza
#
# Crie a string `   ciencia de dados com python   `. Remova os espaços laterais, coloque a frase em formato de título e substitua `python` por `colab`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 4, listas

# %% [markdown]
# ### Exercício 29, criando listas
#
# Crie uma lista com cinco números inteiros e mostre a lista completa.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 30, acessando elementos
#
# Usando uma lista de nomes, mostre o primeiro, o último e o penúltimo elemento.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 31, fatiando listas
#
# Crie uma lista com os números de 1 até 10. Mostre os elementos do índice 2 ao 6, os cinco primeiros e os elementos de dois em dois.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 32, alterando lista
#
# Crie uma lista com três frutas. Troque o segundo elemento por outra fruta e exiba o resultado.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 33, métodos básicos
#
# Crie uma lista vazia. Use `append()` para inserir quatro valores. Depois use `pop()` para remover o último e mostre a lista final.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 34, ordenando
#
# Crie uma lista com números fora de ordem. Exiba a lista original, a lista ordenada em ordem crescente e a lista em ordem decrescente.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 35, aninhamento
#
# Crie uma lista aninhada no formato `[[1,2,3],[4,5,6],[7,8,9]]`. Acesse o número `5` e depois o número `9`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 36, compreensão de lista 1
#
# Use list comprehension para criar uma lista com os quadrados dos números de 1 a 10.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 37, compreensão de lista 2
#
# Use list comprehension para criar uma lista apenas com os números pares entre 1 e 20.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 38, desafio com lista mista
#
# Crie uma lista contendo strings e números. Percorra a lista e mostre apenas os elementos do tipo string.

# %%
# Você pode usar um laço for e type() ou isinstance()

# %% [markdown]
# ## Bloco 5, dicionários

# %% [markdown]
# ### Exercício 39, criando dicionário
#
# Crie um dicionário chamado `aluno` com as chaves `nome`, `idade` e `curso`. Mostre o valor de cada chave separadamente.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 40, adicionando e atualizando
#
# Crie um dicionário com dados de um produto. Depois adicione a chave `estoque` e atualize o preço do produto.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 41, valores compostos
#
# Crie um dicionário em que uma das chaves tenha como valor uma lista. Depois acesse um item específico dessa lista.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 42, dicionário aninhado
#
# Crie um dicionário aninhado representando uma turma, contendo nome da turma, professor e um dicionário interno com duas disciplinas.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 43, métodos de dicionário
#
# Crie um dicionário e use os métodos `.keys()`, `.values()` e `.items()`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 44, desafio com cadastro
#
# Crie um dicionário com dados de três alunos, usando a matrícula como chave e o nome como valor. Depois mostre o nome de um aluno a partir de sua matrícula.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 6, tuplas

# %% [markdown]
# ### Exercício 45, criando tupla
#
# Crie uma tupla com cinco elementos e mostre seu tamanho com `len()`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 46, acessando elementos
#
# Crie uma tupla com nomes de dias da semana e mostre o primeiro e o último elemento.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 47, métodos index e count
#
# Em uma tupla com valores repetidos, use `.index()` para localizar a primeira ocorrência de um valor e `.count()` para contar quantas vezes ele aparece.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 48, comparando lista e tupla
#
# Explique, em comentário, a diferença principal entre lista e tupla. Depois crie um exemplo simples de cada uma.

# %%
# Responda em comentário e em seguida crie uma lista e uma tupla

# %% [markdown]
# ### Exercício 49, desafio de desempacotamento
#
# Crie uma tupla com três valores e desempacote esses valores em três variáveis separadas. Depois exiba cada variável.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 7, conjuntos e booleanos

# %% [markdown]
# ### Exercício 50, criando conjunto
#
# Crie um conjunto vazio, adicione três valores com `.add()` e mostre o resultado.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 51, eliminando repetições
#
# Converta a lista `[1,1,2,2,3,3,4,5,5]` em conjunto e explique, em comentário, o que aconteceu.

# %%
# Faça a conversão e use um comentário para explicar o resultado

# %% [markdown]
# ### Exercício 52, operações com conjuntos
#
# Crie dois conjuntos e mostre a união, a interseção e a diferença entre eles.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 53, booleanos básicos
#
# Crie exemplos de expressões que retornem `True` e outras que retornem `False`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 54, comparações lógicas
#
# Crie três variáveis numéricas e monte expressões usando `and`, `or` e `not`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 55, desafio com pertinência
#
# Crie um conjunto de disciplinas. Verifique se a disciplina `Python` está presente e armazene o resultado em uma variável booleana.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 8, métodos em Python

# %% [markdown]
# ### Exercício 56, método de lista
#
# Crie uma lista e use os métodos `.append()` e `.count()` em exemplos práticos.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 57, método de string
#
# Crie uma string e aplique pelo menos três métodos de string diferentes.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 58, função x método
#
# Explique, em comentário, a diferença entre uma função e um método. Depois mostre um exemplo de função e um exemplo de método.

# %%
# Escreva sua explicação em comentário e depois faça exemplos

# %% [markdown]
# ### Exercício 59, criando uma classe simples
#
# Crie uma classe chamada `Robo` com um método `ligar()` que mostre uma mensagem. Depois crie um objeto e chame o método.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 60, desafio com classe
#
# Crie uma classe chamada `Aluno` com um método `apresentar()` que mostre nome e curso do aluno. Instancie dois objetos e chame o método para ambos.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 9, funções

# %% [markdown]
# ### Exercício 61, função simples
#
# Crie uma função chamada `diga_ola()` que mostre a mensagem `Olá!` e depois chame essa função.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 62, função com parâmetro
#
# Crie uma função chamada `cumprimentar(nome)` que mostre uma saudação personalizada.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 63, função com retorno
#
# Crie uma função chamada `quadrado(numero)` que retorne o quadrado do número informado.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 64, função com dois parâmetros
#
# Crie uma função `somar(a, b)` que receba dois números e retorne a soma.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 65, função com decisão
#
# Crie uma função `verificar_par(n)` que retorne `True` se o número for par e `False` caso contrário.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 66, docstring
#
# Crie uma função com docstring explicando o que ela faz. Depois use `help()` nela.

# %%
def exemplo():
    """Escreva aqui uma docstring adequada."""
    pass

# Depois, use help(exemplo)

# %% [markdown]
# ### Exercício 67, desafio com reutilização
#
# Crie uma função que receba uma lista de números e retorne a média dos valores da lista.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 10, lambda, map e filter

# %% [markdown]
# ### Exercício 68, map com função nomeada
#
# Crie uma função `dobro(x)` e use `map()` para aplicá-la a uma lista de números.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 69, filter com função nomeada
#
# Crie uma função que verifique se um número é par e use `filter()` para filtrar apenas os pares de uma lista.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 70, lambda simples
#
# Crie uma função lambda que receba um número e devolva seu cubo. Teste essa função com alguns valores.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 71, map com lambda
#
# Use `map()` com uma expressão lambda para transformar uma lista de palavras em outra lista contendo o tamanho de cada palavra.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 72, filter com lambda
#
# Use `filter()` com lambda para selecionar apenas palavras com mais de quatro letras de uma lista de strings.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 11, arquivos

# %% [markdown]
# Antes dos exercícios deste bloco, execute a célula abaixo para criar um arquivo de apoio.

# %%
# %%writefile alunos_notas.txt
# Ana,8.5
# Bruno,7.0
# Carla,9.2
# Diego,6.8
# Eva,10.0

# %% [markdown]
# ### Exercício 73, abrindo arquivo
#
# Abra o arquivo `alunos_notas.txt` em modo leitura e exiba todo o conteúdo.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 74, cursor de leitura
#
# Leia o conteúdo do arquivo uma vez. Depois tente ler novamente sem reposicionar o cursor. Explique, em comentário, o que aconteceu.

# %%
# Faça a leitura duas vezes e explique em comentário o comportamento observado

# %% [markdown]
# ### Exercício 75, seek
#
# Abra o arquivo, leia todo o conteúdo, use `seek(0)` para voltar ao início e leia novamente.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 76, readlines
#
# Leia o arquivo usando `readlines()` e mostre quantas linhas existem no arquivo.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 77, escrevendo arquivo
#
# Crie um novo arquivo chamado `resumo.txt` e grave nele três linhas de texto relacionadas à disciplina de Python.

# %%
with open('resumo.txt', 'w', encoding='utf-8') as arquivo:
    # Escreva sua solução aqui
    pass

# %% [markdown]
# ### Exercício 78, desafio com processamento de arquivo
#
# Leia o arquivo `alunos_notas.txt`, separe nome e nota de cada linha e mostre apenas os alunos com nota maior ou igual a 8.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Bloco 12, desafios integradores

# %% [markdown]
# ### Exercício 79, integrador 1
#
# Crie uma lista com nomes de estudantes. Use list comprehension para gerar uma nova lista contendo o tamanho de cada nome. Depois transforme esse resultado em um dicionário no formato `nome: quantidade_de_letras`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 80, integrador 2
#
# Crie uma função que receba uma frase e retorne um dicionário contendo a quantidade de vezes que cada palavra aparece na frase.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 81, integrador 3
#
# Leia o arquivo `alunos_notas.txt` e construa um dicionário em que a chave seja o nome do aluno e o valor seja a nota convertida para `float`.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 82, integrador 4
#
# Crie uma lista de números de 1 a 20. Use `filter()` para manter apenas os pares e `map()` para gerar o quadrado desses números. Mostre o resultado final em lista.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 83, integrador 5
#
# Crie uma tupla com nomes de disciplinas e um conjunto com algumas disciplinas já concluídas. Verifique, para cada disciplina da tupla, se ela está ou não no conjunto de concluídas.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ### Exercício 84, integrador 6
#
# Crie um pequeno sistema em Python sem `input()`, usando variáveis, listas, dicionários e funções, para representar uma turma com pelo menos três alunos e suas notas. Depois calcule e mostre a média de cada aluno.

# %%
# Escreva sua solução aqui

# %% [markdown]
# ## Encerramento
#
# Ao finalizar esta lista, revise:
#
# 1. Se você utilizou corretamente os tipos de dados estudados.
# 2. Se compreendeu a diferença entre modificar objetos e criar novos objetos.
# 3. Se consegue usar funções para organizar melhor as soluções.
# 4. Se já consegue combinar listas, dicionários, arquivos e funções em problemas maiores.
#
# Sugestão de aprofundamento:
#
# 1. Refazer os exercícios mais difíceis sem consultar exemplos anteriores.
# 2. Tentar criar versões com `input()` dos exercícios numéricos e textuais.
# 3. Escolher três desafios integradores e transformá-los em pequenos projetos.
